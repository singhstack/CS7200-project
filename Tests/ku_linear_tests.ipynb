# %%
import pandas as pd
import seaborn as sns
sns.set(context="notebook", palette="Spectral", style = 'darkgrid' ,font_scale = 1.5, color_codes=True)
import warnings
warnings.filterwarnings('ignore')
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from scipy.special import ndtri
from scipy.stats import chi2
from scipy.stats import t
from scipy.stats import f
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.regression.linear_model import OLS

# %% [markdown]
# ### Reduced Model

# %%
df_reduced = pd.read_csv(r'../data/direct_transitivity/d_.csv')
df_reduced.head()
# Out:
#    Index                                  File  Nodes  Total Nodes  \
# 0      0                 north/g.10.72.graphml     10           12
# 1      1                 north/g.13.45.graphml     13           13
# 2      2                 north/g.10.11.graphml     10           10
# 3      3   Rome-Lib/graficon11nodi/grafo233.11     11           18
# 4      4  Rome-Lib/graficon12nodi/grafo2240.12     12           16
#
#    Butterflies  X-vars  C-vars  Total vars  Total constraints  Crossings  \
# 0            0       8       7          15                 18          0
# 1            0      31       2          33                118          0
# 2            0      15       0          15                 40          0
# 3            0      15      12          27                 36          0
# 4            0      12      11          23                 28          0
#
#     Opttime  Status  Nodes visited  Setup Time
# 0  0.001962       2              0       0.028
# 1  0.000073       2              0       0.004
# 2  0.000067       2              0       0.002
# 3  0.000055       2              0       0.002
# 4  0.011561       2              1       0.001

# %%
cols_of_interest = ['Total vars','Total constraints','Total Nodes','Crossings','Opttime']
df_reduced_subset = df_reduced[cols_of_interest]
df_reduced_subset.rename(columns={'Total vars': 'Total_vars','Total constraints': 'Total_constrains','Total Nodes':'Total_nodes'}, inplace=True)
df_reduced_subset.head()
# Out:
#    Total_vars  Total_constrains  Total_nodes  Crossings   Opttime
# 0          15                18           12          0  0.001962
# 1          33               118           13          0  0.000073
# 2          15                40           10          0  0.000067
# 3          27                36           18          0  0.000055
# 4          23                28           16          0  0.011561

# %%
reduced_model = ols(formula=" Opttime ~ Total_vars + Total_constrains + Total_nodes + Crossings", data=df_reduced_subset).fit()

print(reduced_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Opttime   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     917.4
# Date:                Wed, 06 Dec 2023   Prob (F-statistic):               0.00
# Time:                        15:36:35   Log-Likelihood:                -4580.9
# No. Observations:                1150   AIC:                             9172.
# Df Residuals:                    1145   BIC:                             9197.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.9571      1.023      0.936      0.349      -1.049       2.963
# Total_vars           0.0371      0.002     24.136      0.000       0.034       0.040
# Total_constrains    -0.0012   9.33e-05    -13.305      0.000      -0.001      -0.001
# Total_nodes         -0.2743      0.023    -11.928      0.000      -0.319      -0.229
# Crossings           -0.0543      0.007     -8.063      0.000      -0.068      -0.041
# ==============================================================================
# Omnibus:                       45.065   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.353
# Skew:                           0.406   Prob(JB):                     3.52e-13
# Kurtosis:                       3.734   Cond. No.                     5.80e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.8e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sse_r = reduced_model.ssr
df_r = reduced_model.df_resid
print(f"SSE(R) = {sse_r},\nDegrees of freedom = {df_r}")
# Out:
# SSE(R) = 194145.65564334817,
# Degrees of freedom = 1145.0

# %% [markdown]
# ### Full Model

# %%
df_full = pd.read_csv(r'../data/direct_transitivity_data.csv')
df_full.head()
# Out:
#    Index                                  File  Nodes  Total Nodes  \
# 0      0                 north/g.10.72.graphml     10           12
# 1      1                 north/g.13.45.graphml     13           13
# 2      2                 north/g.10.11.graphml     10           10
# 3      3   Rome-Lib/graficon11nodi/grafo233.11     11           18
# 4      4  Rome-Lib/graficon12nodi/grafo2240.12     12           16
#
#    Butterflies  X-vars  C-vars  Total vars  Total constraints  Crossings  ...  \
# 0            0       8       7          15                 20          0  ...
# 1            0       6       2           8                  8          0  ...
# 2            0      15       0          15                 40          0  ...
# 3            0      15      12          27                 36          0  ...
# 4            0      12      11          23                 30          0  ...
#
#      config  check_1  check_2  check_3 check_4  check_5  check_6  check_7  \
# 0  d_235689        0        1        1       0        1        1        0
# 1  d_235689        0        1        1       0        1        1        0
# 2  d_235689        0        1        1       0        1        1        0
# 3  d_235689        0        1        1       0        1        1        0
# 4  d_235689        0        1        1       0        1        1        0
#
#    check_8  check_9
# 0        1        1
# 1        1        1
# 2        1        1
# 3        1        1
# 4        1        1
#
# [5 rows x 24 columns]

# %%
# Out:
# north/g.10.72.graphml                   512
# Rome-Lib/graficon62nodi/grafo4566.62    512
# Rome-Lib/graficon64nodi/grafo9384.64    512
# Rome-Lib/graficon83nodi/grafo6468.83    512
# Rome-Lib/graficon79nodi/grafo9381.79    512
#                                        ...
# Rome-Lib/graficon38nodi/grafo5499.38    512
# Rome-Lib/graficon44nodi/grafo7381.44    512
# Rome-Lib/graficon38nodi/grafo6727.38    512
# Rome-Lib/graficon58nodi/grafo3343.58    512
# Rome-Lib/graficon73nodi/grafo7959.73    512
# Name: File, Length: 1150, dtype: int64

# %%
cols_of_interest = ['File','Total vars','Total constraints','Total Nodes','Crossings', 'check_1', 'check_2', 'check_3', 'check_4',
 'check_5', 'check_6','check_7', 'check_8', 'check_9','Opttime']
df_full_subset = df_full[cols_of_interest]
df_full_subset.rename(columns={'Total vars': 'Total_vars','Total constraints': 'Total_constrains','Total Nodes':'Total_nodes'}, inplace=True)
df_full_subset.head()
# Out:
#                                    File  Total_vars  Total_constrains  \
# 0                 north/g.10.72.graphml          15                20
# 1                 north/g.13.45.graphml           8                 8
# 2                 north/g.10.11.graphml          15                40
# 3   Rome-Lib/graficon11nodi/grafo233.11          27                36
# 4  Rome-Lib/graficon12nodi/grafo2240.12          23                30
#
#    Total_nodes  Crossings  check_1  check_2  check_3  check_4  check_5  \
# 0           12          0        0        1        1        0        1
# 1           13          0        0        1        1        0        1
# 2           10          0        0        1        1        0        1
# 3           18          0        0        1        1        0        1
# 4           16          0        0        1        1        0        1
#
#    check_6  check_7  check_8  check_9   Opttime
# 0        1        0        1        1  0.000556
# 1        1        0        1        1  0.000291
# 2        1        0        1        1  0.000040
# 3        1        0        1        1  0.002283
# 4        1        0        1        1  0.000364

# %%
df_full_subset.groupby(['File']).mean()
# Out:
#                                          Total_vars  Total_constrains  \
# File
# Rome-Lib/graficon100nodi/grafo10372.100     4684.50         21258.500
# Rome-Lib/graficon100nodi/grafo10550.100     4740.75         20871.750
# Rome-Lib/graficon100nodi/grafo10937.100     8550.00         54953.000
# Rome-Lib/graficon100nodi/grafo11613.100     5979.00         31154.750
# Rome-Lib/graficon10nodi/grafo1010.10          46.50            87.500
# ...                                             ...               ...
# north/g.69.3.graphml                         601.50          6912.500
# north/g.69.5.graphml                         628.50          7069.000
# north/g.70.1.graphml                        6945.75         42637.500
# north/g.73.8.graphml                        4418.25         25772.625
# north/g.75.7.graphml                         999.75          3271.000
#
#                                          Total_nodes   Crossings  check_1  \
# File
# Rome-Lib/graficon100nodi/grafo10372.100        190.0   50.519531      0.5
# Rome-Lib/graficon100nodi/grafo10550.100        218.0   39.484375      0.5
# Rome-Lib/graficon100nodi/grafo10937.100        203.0  520.349609      0.5
# Rome-Lib/graficon100nodi/grafo11613.100        231.0   65.232422      0.5
# Rome-Lib/graficon10nodi/grafo1010.10            12.0    0.000000      0.5
# ...                                              ...         ...      ...
# north/g.69.3.graphml                            69.0    0.000000      0.5
# north/g.69.5.graphml                            69.0    0.000000      0.5
# north/g.70.1.graphml                           173.0   95.480469      0.5
# north/g.73.8.graphml                           167.0   34.005859      0.5
# north/g.75.7.graphml                           110.0    0.000000      0.5
#
#                                          check_2  check_3  check_4  check_5  \
# File
# Rome-Lib/graficon100nodi/grafo10372.100      0.5      0.5      0.5      0.5
# Rome-Lib/graficon100nodi/grafo10550.100      0.5      0.5      0.5      0.5
# Rome-Lib/graficon100nodi/grafo10937.100      0.5      0.5      0.5      0.5
# Rome-Lib/graficon100nodi/grafo11613.100      0.5      0.5      0.5      0.5
# Rome-Lib/graficon10nodi/grafo1010.10         0.5      0.5      0.5      0.5
# ...                                          ...      ...      ...      ...
# north/g.69.3.graphml                         0.5      0.5      0.5      0.5
# north/g.69.5.graphml                         0.5      0.5      0.5      0.5
# north/g.70.1.graphml                         0.5      0.5      0.5      0.5
# north/g.73.8.graphml                         0.5      0.5      0.5      0.5
# north/g.75.7.graphml                         0.5      0.5      0.5      0.5
#
#                                          check_6  check_7  check_8  check_9  \
# File
# Rome-Lib/graficon100nodi/grafo10372.100      0.5      0.5      0.5      0.5
# Rome-Lib/graficon100nodi/grafo10550.100      0.5      0.5      0.5      0.5
# Rome-Lib/graficon100nodi/grafo10937.100      0.5      0.5      0.5      0.5
# Rome-Lib/graficon100nodi/grafo11613.100      0.5      0.5      0.5      0.5
# Rome-Lib/graficon10nodi/grafo1010.10         0.5      0.5      0.5      0.5
# ...                                          ...      ...      ...      ...
# north/g.69.3.graphml                         0.5      0.5      0.5      0.5
# north/g.69.5.graphml                         0.5      0.5      0.5      0.5
# north/g.70.1.graphml                         0.5      0.5      0.5      0.5
# north/g.73.8.graphml                         0.5      0.5      0.5      0.5
# north/g.75.7.graphml                         0.5      0.5      0.5      0.5
#
#                                            Opttime
# File
# Rome-Lib/graficon100nodi/grafo10372.100  42.888354
# Rome-Lib/graficon100nodi/grafo10550.100  38.828083
# Rome-Lib/graficon100nodi/grafo10937.100  60.147798
# Rome-Lib/graficon100nodi/grafo11613.100  42.766048
# Rome-Lib/graficon10nodi/grafo1010.10      0.009616
# ...                                            ...
# north/g.69.3.graphml                      0.205033
# north/g.69.5.graphml                      0.202421
# north/g.70.1.graphml                     33.518547
# north/g.73.8.graphml                     12.463597
# north/g.75.7.graphml                      0.042644
#
# [1150 rows x 14 columns]

# %%
' + '.join(list(df_full_subset.columns))
# Out:
# 'Total_vars + Total_constrains + Total_nodes + Crossings + check_1 + check_2 + check_3 + check_4 + check_5 + check_6 + check_7 + check_8 + check_9 + Opttime'

# %%
full_model = ols(formula=" Opttime ~ Total_vars + Total_constrains + Total_nodes + Crossings + check_1 + check_2 + check_3 + check_4 + check_5 + check_6 + check_7 + check_8 + check_9", data=df_full_subset).fit()

print(full_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Opttime   R-squared:                       0.658
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                 8.696e+04
# Date:                Wed, 06 Dec 2023   Prob (F-statistic):               0.00
# Time:                        15:47:17   Log-Likelihood:            -2.4328e+06
# No. Observations:              588800   AIC:                         4.866e+06
# Df Residuals:                  588786   BIC:                         4.866e+06
# Df Model:                          13
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -3.4540      0.080    -42.955      0.000      -3.612      -3.296
# Total_vars           0.0047   2.31e-05    204.954      0.000       0.005       0.005
# Total_constrains    -0.0002   3.21e-06    -64.011      0.000      -0.000      -0.000
# Total_nodes          0.1370      0.001    228.807      0.000       0.136       0.138
# Crossings            0.0257      0.000     98.297      0.000       0.025       0.026
# check_1             -7.0429      0.039   -178.804      0.000      -7.120      -6.966
# check_2             -0.0126      0.039     -0.321      0.748      -0.090       0.064
# check_3              1.9708      0.039     50.161      0.000       1.894       2.048
# check_4             -8.7136      0.056   -154.805      0.000      -8.824      -8.603
# check_5              0.0560      0.039      1.423      0.155      -0.021       0.133
# check_6              0.0294      0.039      0.749      0.454      -0.048       0.106
# check_7             -0.3995      0.039    -10.170      0.000      -0.477      -0.323
# check_8              0.2961      0.039      7.521      0.000       0.219       0.373
# check_9              1.1058      0.039     28.146      0.000       1.029       1.183
# ==============================================================================
# Omnibus:                    13540.896   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22575.777
# Skew:                           0.214   Prob(JB):                         0.00
# Kurtosis:                       3.859   Cond. No.                     1.17e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sse_f = full_model.ssr
df_f = full_model.df_resid
print(f"SSE(F) = {sse_f},\nDegrees of freedom = {df_f}")
# Out:
# SSE(F) = 133763820.01076062,
# Degrees of freedom = 588786.0

# %% [markdown]
# ### F-test

# %%
alpha = 0.05
f_star = ((sse_r - sse_f)/(df_r - df_f))/(sse_f/df_f)
f_star

critical_value = f.ppf(1-alpha, df_r - df_f, df_f)

if (f_star <= critical_value):
    print(f'Conclude Null with f_star={f_star} and crtical value={critical_value}')
else:
    print(f'Conclude Alternate with f_star={f_star} and crtical value={critical_value}')
# Out:
# Conclude Alternate with f_star=1.000494234184039 and crtical value=nan
